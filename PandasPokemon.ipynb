# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandrika-Saha/Machine-Learning-Algos/blob/main/PandasPokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df['Name'][0:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[['Name', 'HP', 'Attack']]
# Out:
#                       Name  HP  Attack
# 0                Bulbasaur  45      49
# 1                  Ivysaur  60      62
# 2                 Venusaur  80      82
# 3    VenusaurMega Venusaur  80     100
# 4               Charmander  39      52
# ..                     ...  ..     ...
# 795                Diancie  50     100
# 796    DiancieMega Diancie  50     160
# 797    HoopaHoopa Confined  80     110
# 798     HoopaHoopa Unbound  80     160
# 799              Volcanion  80     110
#
# [800 rows x 3 columns]

# %%
df[['Name', 'HP', 'Attack']][0:5]
# Out:
#                     Name  HP  Attack
# 0              Bulbasaur  45      49
# 1                Ivysaur  60      62
# 2               Venusaur  80      82
# 3  VenusaurMega Venusaur  80     100
# 4             Charmander  39      52

# %%
print(df.iloc[0])
print(df.iloc[0:5])
print(df.iloc[0, 3])
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
for i, r in df.iterrows():
  print(i, r)
# Out:
# Streaming output truncated to the last 5000 lines.
# Attack            50
# Defense          100
# Sp. Atk          100
# Sp. Def          200
# Speed             50
# Generation         3
# Legendary       True
# Name: 415, dtype: object
# 416 #                   379
# Name          Registeel
# Type 1            Steel
# Type 2              NaN
# HP                   80
# Attack               75
# Defense             150
# Sp. Atk              75
# Sp. Def             150
# Speed                50
# Generation            3
# Legendary          True
# Name: 416, dtype: object
# 417 #                 380
# Name           Latias
# Type 1         Dragon
# Type 2        Psychic
# HP                 80
# Attack             80
# Defense            90
# Sp. Atk           110
# Sp. Def           130
# Speed             110
# Generation          3
# Legendary        True
# Name: 417, dtype: object
# 418 #                           380
# Name          LatiasMega Latias
# ...

# %%
for i, r in df.iterrows():
  print(i, r['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.loc[df['Defense']>150]
# Out:
#        #                   Name   Type 1   Type 2   HP  Attack  Defense  \
# 87    80    SlowbroMega Slowbro    Water  Psychic   95      75      180
# 98    91               Cloyster    Water      Ice   50      95      180
# 103   95                   Onix     Rock   Ground   35      45      160
# 223  208                Steelix    Steel   Ground   75      85      200
# 224  208    SteelixMega Steelix    Steel   Ground   75     125      230
# 230  213                Shuckle      Bug     Rock   20      10      230
# 332  306                 Aggron    Steel     Rock   70     110      180
# 333  306      AggronMega Aggron    Steel      NaN   70     140      230
# 414  377               Regirock     Rock      NaN   80     100      200
# 424  383  GroudonPrimal Groudon   Ground     Fire  100     180      160
# 430  386    DeoxysDefense Forme  Psychic      NaN   50      70      160
# 456  411              Bastiodon     Rock    Steel   60      52      168
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe().T
# Out:
#             count       mean         std   min     25%    50%     75%    max
# #           800.0  362.81375  208.343798   1.0  184.75  364.5  539.25  721.0
# HP          800.0   69.25875   25.534669   1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366   5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501   5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294  10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916  20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474   5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290   1.0    2.00    3.0    5.00    6.0

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'Type 1'])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'Type 1'], ascending=[True, False])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Total'] = df['Attack'] + df['Defense']

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     98
# 1       80     60           1      False    125
# 2      100     80           1      False    165
# 3      120     80           1      False    223
# 4       50     65           1      False     95

# %%
df.drop(columns=['Total'], inplace=True)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:, 4:6].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
columns = list(df.columns.values)
print(columns)
df = df[columns[0:4] + [columns[-1]] + columns[4:12]]
df.head(5)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison     94  45      49       49
# 1  2                Ivysaur  Grass  Poison    122  60      62       63
# 2  3               Venusaur  Grass  Poison    162  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    180  80     100      123
# 4  4             Charmander   Fire     NaN     91  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.to_csv('chandged.csv')

# %%
df.to_csv('changed2.csv', index=False)

# %% [markdown]
# # Filtering data

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)].reset_index(drop=True)
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    162   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    180   80     100      123
# 2   45              Vileplume  Grass  Poison    155   75      80       85
# 3   71             Victreebel  Grass  Poison    185   80     105       65
# 4  591              Amoonguss  Grass  Poison    199  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
df.loc[df['Name'].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    180   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    208   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    182   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    182   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    215   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    163   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    105   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    170   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    125   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    230  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    220   65     155
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison     94   45      49       49
# 1      2              Ivysaur    Grass  Poison    122   60      62       63
# 2      3             Venusaur    Grass  Poison    162   80      82       83
# 4      4           Charmander     Fire     NaN     91   39      52       43
# 5      5           Charmeleon     Fire     NaN    122   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    208  108     100      121
# 795  719              Diancie     Rock   Fairy    150   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    190   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    240   80     160       60
# 799  721            Volcanion     Fire   Water    190   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison     94   45      49       49
# 1      2                Ivysaur  Grass  Poison    122   60      62       63
# 2      3               Venusaur  Grass  Poison    162   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    180   80     100      123
# 4      4             Charmander   Fire     NaN     91   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    112   62      50       58
# 736  668                 Pyroar   Fire  Normal    154   86      68       72
# 740  672                 Skiddo  Grass     NaN    131   66      65       48
# 741  673                 Gogoat  Grass     NaN    223  123     100       62
# 799  721              Volcanion   Fire   Water    190   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'].str.contains('^pidg[a-z]*', flags=re.I, regex=True)]
# Out:
#      #                 Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 20  16               Pidgey  Normal  Flying     85  40      45       40
# 21  17            Pidgeotto  Normal  Flying    123  63      60       55
# 22  18              Pidgeot  Normal  Flying    163  83      80       75
# 23  18  PidgeotMega Pidgeot  Normal  Flying    163  83      80       80
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20       35       35     56           1      False
# 21       50       50     71           1      False
# 22       70       70    101           1      False
# 23      135       80    121           1      False

# %%
df.loc[df['Name'].str.contains('^pidg[a-z]$', flags=re.I, regex=True)]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
df.loc[df['Name'].str.contains('^pidg[a-z]{2}$', flags=re.I, regex=True)]
# Out:
#      #    Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16  Pidgey  Normal  Flying     85  40      45       40       35       35
#
#     Speed  Generation  Legendary
# 20     56           1      False

# %%
df.loc[df['Name'].str.contains('[a-z]*ing$', flags=re.I, regex=True)]
# Out:
#        #        Name   Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 39    34    Nidoking   Poison   Ground    183   81     102       77       85
# 117  109     Koffing   Poison      NaN    105   40      65       95       60
# 118  110     Weezing   Poison      NaN    155   65      90      120       85
# 128  119     Seaking    Water      NaN    172   80      92       65       65
# 214  199    Slowking    Water  Psychic    170   95      75       80      100
# 235  217    Ursaring   Normal      NaN    220   90     130       75       75
# 313  289     Slaking   Normal      NaN    310  150     160      100       95
# 481  433   Chingling  Psychic      NaN     75   45      30       50       65
# 646  585    Deerling   Normal    Grass    120   60      60       50       40
# 729  661  Fletchling   Normal   Flying     95   45      50       43       40
#
#      Sp. Def  Speed  Generation  Legendary
# 39        75     85           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison     94  45      49       49
# 1      2                Ivysaur    Grass  Poison    122  60      62       63
# 2      3               Venusaur    Grass  Poison    162  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    180  80     100      123
# 4      4             Charmander   Flamer     NaN     91  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    150  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    210  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    190  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    240  80     160       60
# 799  721              Volcanion   Flamer   Water    190  80     110      120
#
# ...

# %%
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison     94  45      49       49
# 1  2                Ivysaur  Grass  Poison    122  60      62       63
# 2  3               Venusaur  Grass  Poison    162  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    180  80     100      123
# 4  4             Charmander   Fire     NaN     91  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison     94  45      49       49
# 1  2                Ivysaur  Grass  Poison    122  60      62       63
# 2  3               Venusaur  Grass  Poison    162  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    180  80     100      123
# 4  4             Charmander   Fire     NaN     91  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1       True

# %%
df.loc[df['HP'] > 40, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']
# Out:
# /tmp/ipython-input-1445532974.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Test 1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['HP'] > 40, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']
# /tmp/ipython-input-1445532974.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Test 2' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df['HP'] > 40, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison     94  45      49       49
# 1  2                Ivysaur  Grass  Poison    122  60      62       63
# 2  3               Venusaur  Grass  Poison    162  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    180  80     100      123
# 4  4             Charmander   Fire     NaN     91  39      52       43
#
#    Sp. Atk  Sp. Def  Speed Generation Legendary
# 0       65       65     45     Test 1    Test 2
# 1       80       80     60     Test 1    Test 2
# 2      100      100     80     Test 1    Test 2
# 3      122      120     80     Test 1    Test 2
# 4       60       50     65          1      True

# %%
df.groupby(['Type 2']).mean(numeric_only=True).sort_values('HP', ascending=True)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 2
# Bug       382.000000  143.333333  53.333333   90.000000   80.000000
# Poison    169.970588  126.352941  58.764706   67.588235   59.558824
# Ghost     551.714286  143.285714  59.142857   84.142857   82.285714
# Grass     505.400000  136.800000  62.640000   74.160000   80.120000
# Water     400.000000  132.857143  62.714286   70.142857   85.071429
# Normal    681.000000  116.250000  63.500000   52.750000   53.750000
# Fairy     379.043478  125.913043  64.304348   61.608696   73.869565
# Steel     435.636364  157.227273  64.636364   92.590909  104.636364
# Rock      347.785714  152.071429  68.071429   84.000000  126.857143
# Fire      481.833333  152.500000  71.250000   81.250000   80.166667
# Flying    331.103093  151.680412  71.391753   80.288660   68.309278
# Psychic   337.151515  146.909091  72.212121   74.696970   87.030303
# Dark      413.850000  185.350000  75.550000  109.800000   72.050000
# ...

# %%
print(sorted(df['Type 1'].unique()))
# Out:
# ['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire', 'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison', 'Psychic', 'Rock', 'Steel', 'Water']

# %%
print(len(sorted(df['Type 1'].dropna().unique())))
# Out:
# 18

# %%
df['Types'] = df['Type 1'] + "&" + df['Type 2']
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison     94  45      49       49
# 1  2                Ivysaur  Grass  Poison    122  60      62       63
# 2  3               Venusaur  Grass  Poison    162  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    180  80     100      123
# 4  4             Charmander   Fire     NaN     91  39      52       43
#
#    Sp. Atk  Sp. Def  Speed Generation Legendary         Types
# 0       65       65     45     Test 1    Test 2  Grass&Poison
# 1       80       80     60     Test 1    Test 2  Grass&Poison
# 2      100      100     80     Test 1    Test 2  Grass&Poison
# 3      122      120     80     Test 1    Test 2  Grass&Poison
# 4       60       50     65          1      True           NaN

# %%
df.groupby(['Types']).sum(numeric_only=True)
# Out:
#                   #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Types
# Bug&Electric   1191    244  120     124      110      154      110    173
# Bug&Fighting    428    470  160     310      190       80      200    160
# Bug&Fire       1273    285  140     145      120      185      160    160
# Bug&Flying     4008   1864  882     982      862     1020      967   1160
# Bug&Ghost       292     91    1      90       45       30       30     40
# ...             ...    ...  ...     ...      ...      ...      ...    ...
# Water&Ice       309    520  270     250      340      240      235    200
# Water&Poison    356    390  185     205      175      185      275    255
# Water&Psychic   559    800  435     365      520      470      395    220
# Water&Rock     1720    614  283     331      451      246      260    144
# Water&Steel     395    170   84      86       88      111      101     60
#
# [136 rows x 8 columns]

# %%
df['count'] = 1
df.groupby('Type 1').sum(numeric_only=True)['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']).sum(numeric_only=True)
# Out:
#                     #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric  1191    244  120     124      110      154      110    173
#        Fighting   428    470  160     310      190       80      200    160
#        Fire      1273    285  140     145      120      185      160    160
#        Flying    4008   1864  882     982      862     1020      967   1160
#        Ghost      292     91    1      90       45       30       30     40
# ...               ...    ...  ...     ...      ...      ...      ...    ...
# Water  Ice        309    520  270     250      340      240      235    200
#        Poison     356    390  185     205      175      185      275    255
#        Psychic    559    800  435     365      520      470      395    220
#        Rock      1720    614  283     331      451      246      260    144
#        Steel      395    170   84      86       88      111      101     60
#
#                  count
# Type 1 Type 2
# ...

# %%
df.groupby('Type 1')['HP'].median()
# Out:
# Type 1
# Bug         60.0
# Dark        65.0
# Dragon      80.0
# Electric    60.0
# Fairy       78.0
# Fighting    70.0
# Fire        70.0
# Flying      79.0
# Ghost       59.5
# Grass       65.5
# Ground      75.0
# Ice         70.0
# Normal      70.0
# Poison      67.5
# Psychic     68.0
# Rock        68.5
# Steel       60.0
# Water       70.0
# Name: HP, dtype: float64

# %%
import numpy as np
df.groupby('Type 1')['HP'].aggregate(['min', np.median, np.std])
# Out:
# /tmp/ipython-input-192562578.py:2: FutureWarning: The provided callable <function median at 0x7994fff29b20> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby('Type 1')['HP'].aggregate(['min', np.median, np.std])
# /tmp/ipython-input-192562578.py:2: FutureWarning: The provided callable <function std at 0x7995031f9bc0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby('Type 1')['HP'].aggregate(['min', np.median, np.std])
#           min  median        std
# Type 1
# Bug         1    60.0  16.328914
# Dark       35    65.0  21.078297
# Dragon     41    80.0  23.795415
# Electric   20    60.0  17.306511
# Fairy      35    78.0  23.587291
# Fighting   30    70.0  25.852695
# Fire       38    70.0  19.404123
# ...

# %%
df.groupby('Types').aggregate({'HP': 'min', 'Attack':'max', 'Defense': 'median'})
# Out:
#                HP  Attack  Defense
# Types
# Bug&Electric   50      77     55.0
# Bug&Fighting   80     185     95.0
# Bug&Fire       55      85     60.0
# Bug&Flying     30     155     50.0
# Bug&Ghost       1      90     45.0
# ...            ..     ...      ...
# Water&Ice      50      95     80.0
# Water&Poison   40      95     65.0
# Water&Psychic  60      75     85.0
# Water&Rock     54     108    116.5
# Water&Steel    84      86     88.0
#
# [136 rows x 3 columns]

# %%
df.groupby('Type 1')[['HP', 'Attack', 'Defense']].std()
# Out:
#                  HP     Attack    Defense
# Type 1
# Bug       16.328914  37.040904  33.617609
# Dark      21.078297  25.774247  25.121982
# Dragon    23.795415  33.742622  24.102938
# Electric  17.306511  23.764169  24.757033
# Fairy     23.587291  29.751298  18.979478
# Fighting  25.852695  28.290163  18.578163
# Fire      19.404123  28.769275  23.658200
# Flying    20.694202  37.500000  21.360009
# Ghost     31.685895  29.629687  32.551138
# Grass     19.516564  25.380520  24.485192
# Ground    25.662492  33.059087  33.786912
# Ice       21.286861  27.289511  34.387708
# Normal    36.233430  30.295862  23.771833
# Poison    19.665019  19.630010  21.066128
# Psychic   28.421340  42.309265  28.359401
# Rock      20.833884  35.325458  36.447209
# Steel     16.044010  30.388276  44.806548
# Water     27.487026  28.377192  27.773809

# %%
def filter_func(x):
  return x['HP'].std() > 20

# %%
df.groupby('Type 1').filter(filter_func).reset_index(drop=True).set_index('Type 1')
# Out:
#            #                     Name  Type 2  Total   HP  Attack  Defense  \
# Type 1
# Water      7                 Squirtle     NaN     92   44      48       65
# Water      8                Wartortle     NaN    122   59      63       80
# Water      9                Blastoise     NaN    162   79      83      100
# Water      9  BlastoiseMega Blastoise     NaN    182   79     103      120
# Normal    16                   Pidgey  Flying     85   40      45       40
# ...      ...                      ...     ...    ...  ...     ...      ...
# Dragon   718         Zygarde50% Forme  Ground    208  108     100      121
# Rock     719                  Diancie   Fairy    150   50     100      150
# Rock     719      DiancieMega Diancie   Fairy    210   50     160      110
# Psychic  720      HoopaHoopa Confined   Ghost    190   80     110       60
# Psychic  720       HoopaHoopa Unbound    Dark    240   80     160       60
#
# ...

# %%
df3 = {
    'key': ['A', 'B', 'C', 'A', 'C'],
    'data1': [0, 1, 2, 3, 4],
    'data2': [5, 6, 7, 8, 9]
}
df3 = pd.DataFrame(df3)
df3
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      6
# 2   C      2      7
# 3   A      3      8
# 4   C      4      9

# %%
df3.groupby('key').mean()
# Out:
#      data1  data2
# key
# A      1.5    6.5
# B      1.0    6.0
# C      3.0    8.0

# %%
def fun(x):
  return x['data1'].mean() >= 2

# %%
df3.groupby('key').filter(fun).reset_index(drop=True)
# Out:
#   key  data1  data2
# 0   C      2      7
# 1   C      4      9

# %%
df.groupby('Type 1')['HP'].transform(lambda x: x-x.mean())
# Out:
# 0     -22.271429
# 1      -7.271429
# 2      12.728571
# 3      12.728571
# 4     -30.903846
#          ...
# 795   -15.363636
# 796   -15.363636
# 797     9.368421
# 798     9.368421
# 799    10.096154
# Name: HP, Length: 800, dtype: float64

# %%
def norm_by_data(x):
  x['Attack'] /= x['HP'].sum()
  return x

df.groupby('Type 1')[['HP', 'Attack']].apply(norm_by_data)
# Out:
#             HP    Attack
# Type 1
# Bug    13   45  0.007643
#        14   50  0.005096
#        15   60  0.011465
#        16   40  0.008917
#        17   45  0.006369
# ...         ..       ...
# Water  724  41  0.006938
#        725  54  0.007806
#        726  72  0.011771
#        762  50  0.006567
#        763  71  0.009045
#
# [800 rows x 2 columns]

# %%
import random
lst = []
for i in range(len(df)):
  lst.append(random.randint(0, 3))

print(lst)
df['lst'] = lst
df.groupby('lst').sum(numeric_only=True)['count']
# Out:
# [2, 2, 3, 3, 1, 3, 1, 3, 0, 2, 1, 0, 2, 3, 3, 1, 0, 3, 2, 0, 2, 3, 0, 2, 0, 2, 2, 3, 0, 1, 3, 0, 1, 1, 3, 1, 1, 1, 2, 1, 3, 1, 0, 2, 0, 2, 2, 2, 3, 3, 0, 0, 2, 2, 2, 0, 0, 2, 3, 3, 2, 1, 3, 1, 2, 1, 1, 3, 1, 0, 1, 0, 3, 1, 2, 1, 1, 3, 2, 2, 3, 3, 0, 3, 2, 0, 2, 0, 3, 2, 3, 2, 0, 2, 3, 0, 1, 0, 0, 2, 1, 2, 1, 0, 3, 3, 1, 2, 3, 3, 0, 3, 2, 3, 0, 0, 2, 2, 3, 3, 3, 1, 1, 0, 3, 2, 1, 0, 2, 3, 3, 1, 2, 1, 0, 1, 3, 3, 1, 1, 3, 2, 0, 0, 3, 0, 0, 1, 1, 0, 1, 0, 0, 0, 0, 0, 0, 2, 0, 2, 2, 2, 3, 1, 2, 2, 2, 2, 1, 1, 0, 3, 3, 1, 1, 1, 3, 1, 1, 0, 3, 0, 1, 3, 1, 3, 1, 3, 2, 1, 0, 3, 2, 1, 2, 3, 2, 3, 0, 2, 3, 1, 0, 1, 1, 1, 3, 2, 3, 0, 2, 0, 0, 3, 3, 1, 3, 2, 1, 2, 3, 2, 0, 2, 1, 3, 2, 1, 0, 3, 3, 1, 0, 2, 2, 0, 2, 1, 1, 0, 3, 3, 3, 0, 3, 2, 1, 2, 0, 1, 1, 2, 3, 2, 3, 3, 3, 2, 3, 0, 2, 0, 2, 2, 3, 1, 1, 2, 1, 2, 1, 0, 3, 0, 2, 2, 0, 3, 3, 0, 0, 0, 1, 3, 3, 0, 1, 3, 0, 0, 1, 0, 3, 3, 2, 2, 3, 3, 1, 1, 3, 3, 3, 3, 3, 3, 3, 0, 0, 2, 2, 2, 0, 3, 1, 1, 2, 2, 1, 3, 2, 2, 0, 1, 3, 2, 0, 2, 2, 2, 3, 0, 0
# ...

# %%
df2 = df.set_index('Type 1')
df2
# Out:
#            #                   Name  Type 2  Total  HP  Attack  Defense  \
# Type 1
# Grass      1              Bulbasaur  Poison     94  45      49       49
# Grass      2                Ivysaur  Poison    122  60      62       63
# Grass      3               Venusaur  Poison    162  80      82       83
# Grass      3  VenusaurMega Venusaur  Poison    180  80     100      123
# Fire       4             Charmander     NaN     91  39      52       43
# ...      ...                    ...     ...    ...  ..     ...      ...
# Rock     719                Diancie   Fairy    150  50     100      150
# Rock     719    DiancieMega Diancie   Fairy    210  50     160      110
# Psychic  720    HoopaHoopa Confined   Ghost    190  80     110       60
# Psychic  720     HoopaHoopa Unbound    Dark    240  80     160       60
# Fire     721              Volcanion   Water    190  80     110      120
#
#          Sp. Atk  Sp. Def  Speed Generation Legendary          Types  count  \
# Type 1
# ...

# %% [markdown]
# # Some lambdas

# %%
add = lambda a, b: a + b
print(add(3, 8))
# Out:
# 11

# %%
def add2(a=4, b=2):
  return a + b
print(add2())
# Out:
# 6

# %%
add = lambda a: a+5
print(add(5))
# Out:
# 10

# %%
(lambda a, b: a+b)(3, 5)
# Out:
# 8

# %%
product = lambda x, y, z = 7: x*y*z
print(product(z=5, x=1, y=1))
# Out:
# 5

# %%
add = lambda *args: sum(args)
print(add(1, 2, 3, 4, 5))
# Out:
# 15

# %%
h_o = lambda x, fun: x + fun(x)
h_o(5, lambda x: x*x)
# Out:
# 30

# %%
print(12%5)
# Out:
# 2

# %%
(lambda x: (x%2) and 'odd' or 'even')(11)
# Out:
# 'odd'

# %%
s_str = lambda string: string in 'Python classes'
s_str('Python')
# Out:
# True

# %%
nums = [10, 40, 80, 160, 240]
g = list(filter(lambda num: num > 80, nums))

# %%
list(filter(lambda num: (num%4) == 0, nums))
# Out:
# [40, 80, 160, 240]

# %%
g
# Out:
# [160, 240]

# %%
d = list(map(lambda x: x*2, nums))
d
# Out:
# [20, 80, 160, 320, 480]

# %%
from functools import reduce
nums= [1,2]
summ = reduce((lambda x, y: x/y), nums)
summ
# Out:
# 0.5

# %%
def quadract(a, b, c):
  return lambda x: a*x**2 + b*x + c
f = quadract(2, 3, 5)
print(f(1))
# Out:
# 10

# %%
import pandas as pd

table1 = pd.DataFrame(data = {'col1': [1, 2, 3], 'col2': [4, 5, 6]})
table2 = pd.DataFrame(data = {'col1': [4, 5, 6], 'col2': [7, 8, 9]})
table3 = pd.DataFrame(data = {'col3': [1, 1, 2], 'col4': [4, 4, 6]})
print(table1)
print(table2)
print(table3)
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
#    col1  col2
# 0     4     7
# 1     5     8
# 2     6     9
#    col3  col4
# 0     1     4
# 1     1     4
# 2     2     6

# %%
pd.concat([table1, table2])
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 0     4     7
# 1     5     8
# 2     6     9

# %%
print(table1)
print(table2)
pd.merge(table1, table2, on='col2', how='right')
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
#    col1  col2
# 0     4     7
# 1     5     8
# 2     6     9
#    col1_x  col2  col1_y
# 0     NaN     7       4
# 1     NaN     8       5
# 2     NaN     9       6

# %%
pd.concat([table1, table3])
# Out:
#    col1  col2  col3  col4
# 0   1.0   4.0   NaN   NaN
# 1   2.0   5.0   NaN   NaN
# 2   3.0   6.0   NaN   NaN
# 0   NaN   NaN   1.0   4.0
# 1   NaN   NaN   1.0   4.0
# 2   NaN   NaN   2.0   6.0

# %%
table1 = pd.DataFrame(data = {'col1': [1, 2, 3], 'col2': [4, 5, 6]})
table2 = pd.DataFrame(data = {'col1': [4, 5, 6], 'col2': [4, 5, 9]})
table3 = pd.DataFrame(data = {'col3': [1, 1, 2], 'col4': [4, 4, 6]})
print(table1)
print(table2)
pd.merge(table1, table2, on='col2', how='outer')
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
#    col1  col2
# 0     4     4
# 1     5     5
# 2     6     9
#    col1_x  col2  col1_y
# 0     1.0     4     4.0
# 1     2.0     5     5.0
# 2     3.0     6     NaN
# 3     NaN     9     6.0

# %%
table1 = pd.DataFrame(data = {'col1': [1, 2, 3], 'col2': [4, 5, 6]})
table2 = pd.DataFrame(data = {'col1': [4, 5, 6], 'col2': [4, 5, 9]})
table3 = pd.DataFrame(data = {'col3': [1, 1, 2], 'col4': [6, 8, 9]})
print(table1)
print(table3)
pd.merge(table1, table3, left_on='col2', right_on='col4', how='left')
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
#    col3  col4
# 0     1     6
# 1     1     8
# 2     2     9
#    col1  col2  col3  col4
# 0     1     4   NaN   NaN
# 1     2     5   NaN   NaN
# 2     3     6   1.0   6.0

# %%
print(table1)
print(table3)

# col1 col2 col3 col4
# 1, 4, 1, 4
# 1, 4, 1, 4
# 2, 5, 2, 6
# 3, 6, NaN, NaN
pd.merge(table1, table3, left_on='col2', right_on='col4', how='outer')
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
#    col3  col4
# 0     1     6
# 1     1     8
# 2     2     9
#    col1  col2  col3  col4
# 0   1.0   4.0   NaN   NaN
# 1   2.0   5.0   NaN   NaN
# 2   3.0   6.0   1.0   6.0
# 3   NaN   NaN   1.0   8.0
# 4   NaN   NaN   2.0   9.0

# %%
print(table1)
print(table3)
pd.merge(table1, table3, left_on='col2', right_on='col4', how='inner')
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
#    col3  col4
# 0     1     6
# 1     1     8
# 2     2     9
#    col1  col2  col3  col4
# 0     3     6     1     6

# %%
print(table1)
print(table3)
pd.merge(table1, table3, left_on='col2', right_on='col4', how='right')
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
#    col3  col4
# 0     1     6
# 1     1     8
# 2     2     9
#    col1  col2  col3  col4
# 0   3.0   6.0     1     6
# 1   NaN   NaN     1     8
# 2   NaN   NaN     2     9
